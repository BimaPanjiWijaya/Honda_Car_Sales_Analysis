# %%
import pandas as pd
import numpy as np

# %%
consumen=pd.read_csv("honda_consumen.csv")
consumen.head()
# Out:
#    Year   Make                      Model Condition     Price  \
# 0  2023  Honda              Ridgeline RTL       New  $46,370
# 1  2023  Honda          CR-V Hybrid Sport       New  $34,150
# 2  2023  Honda          CR-V Hybrid Sport       New  $34,245
# 3  2022  Honda           Pilot TrailSport       New  $46,500
# 4  2023  Honda  CR-V Hybrid Sport Touring       New  $40,395
#
#    Consumer_Rating  Consumer_Review_#           Exterior_Color Interior_Color  \
# 0              4.8                  9     Platinum White Pearl          Beige
# 1              1.7                 24     Platinum White Pearl          Black
# 2              4.7               2869  Meteorite Gray Metallic          Black
# 3              5.0                 12         Sonic Gray Pearl          Black
# 4              4.4                 12      Crystal Black Pearl          Black
#
#           Drivetrain    MPG Fuel_Type       Transmission  \
# 0    All-wheel Drive    NaN  Gasoline          Automatic
# ...

# %%
consumen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               4999 non-null   int64
#  1   Make               4999 non-null   object
#  2   Model              4999 non-null   object
#  3   Condition          4999 non-null   object
#  4   Price              4999 non-null   object
#  5   Consumer_Rating    4999 non-null   float64
#  6   Consumer_Review_#  4999 non-null   int64
#  7   Exterior_Color     4988 non-null   object
#  8   Interior_Color     4988 non-null   object
#  9   Drivetrain         4988 non-null   object
#  10  MPG                3514 non-null   object
#  11  Fuel_Type          4988 non-null   object
#  12  Transmission       4988 non-null   object
#  13  Engine             4988 non-null   object
#  14  VIN                4988 non-null   object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
consumen.describe(include='all')
# Out:
#                Year   Make      Model Condition     Price  Consumer_Rating  \
# count   4999.000000   4999       4999      4999      4999      4999.000000
# unique          NaN      1        146         3      2333              NaN
# top             NaN  Honda  CR-V EX-L       New  $41,770               NaN
# freq            NaN   4999        268      2697        70              NaN
# mean    2020.507702    NaN        NaN       NaN       NaN         4.569654
# std        3.711361    NaN        NaN       NaN       NaN         0.542453
# min     1981.000000    NaN        NaN       NaN       NaN         1.200000
# 25%     2019.000000    NaN        NaN       NaN       NaN         4.400000
# 50%     2022.000000    NaN        NaN       NaN       NaN         4.700000
# 75%     2023.000000    NaN        NaN       NaN       NaN         4.900000
# max     2023.000000    NaN        NaN       NaN       NaN         5.000000
#
#         Consumer_Review_#        Exterior_Color Interior_Color  \
# ...

# %%
consumen.duplicated().value_counts()
# Out:
# False    4999
# dtype: int64

# %%
consumen=consumen.dropna()

# %%
consumen.shape
# Out:
# (3514, 15)

# %%
consumen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3514 entries, 3 to 4997
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               3514 non-null   int64
#  1   Make               3514 non-null   object
#  2   Model              3514 non-null   object
#  3   Condition          3514 non-null   object
#  4   Price              3514 non-null   object
#  5   Consumer_Rating    3514 non-null   float64
#  6   Consumer_Review_#  3514 non-null   int64
#  7   Exterior_Color     3514 non-null   object
#  8   Interior_Color     3514 non-null   object
#  9   Drivetrain         3514 non-null   object
#  10  MPG                3514 non-null   object
#  11  Fuel_Type          3514 non-null   object
#  12  Transmission       3514 non-null   object
#  13  Engine             3514 non-null   object
#  14  VIN                3514 non-null   object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
consumen.to_csv("consumen_clean.csv", index=False)

# %%
import pandas as pd
import numpy as np

# %%
rating=pd.read_csv("honda_rating.csv")
rating.head()
# Out:
#    Year   Make                      Model Condition     Price   Stock_#  \
# 0  2023  Honda              Ridgeline RTL       New  $46,370     830164
# 1  2023  Honda          CR-V Hybrid Sport       New  $34,150    6402953
# 2  2023  Honda          CR-V Hybrid Sport       New  $34,245   PH704805
# 3  2022  Honda           Pilot TrailSport       New  $46,500   5700429B
# 4  2023  Honda  CR-V Hybrid Sport Touring       New  $40,395    5705954
#
#   Mileage  Comfort_Rating  Interior_Design_Rating  Performance_Rating  \
# 0      10             5.0                     4.8                 4.8
# 1       –             5.0                     3.0                 4.0
# 2       1             5.0                     3.0                 4.0
# 3       5             5.0                     5.0                 5.0
# 4       5             5.0                     3.0                 4.0
#
#    Value_For_Money_Rating  Exterior_Styling_Rating  Reliability_Rating State  \
# ...

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     4999 non-null   int64
#  1   Make                     4999 non-null   object
#  2   Model                    4999 non-null   object
#  3   Condition                4999 non-null   object
#  4   Price                    4999 non-null   object
#  5   Stock_#                  4988 non-null   object
#  6   Mileage                  4988 non-null   object
#  7   Comfort_Rating           4447 non-null   float64
#  8   Interior_Design_Rating   4447 non-null   float64
#  9   Performance_Rating       4447 non-null   float64
#  10  Value_For_Money_Rating   4447 non-null   float64
#  11  Exterior_Styling_Rating  4447 non-null   float64
#  12  Reliability_Rating       4447 non-null   float64
#  13  State                    4926 non-null   object
# ...

# %%
rating.describe(include='all')
# Out:
#                Year   Make      Model Condition     Price Stock_# Mileage  \
# count   4999.000000   4999       4999      4999      4999    4988    4988
# unique          NaN      1        146         3      2333    4965    2416
# top             NaN  Honda  CR-V EX-L       New  $41,770   H23100       5
# freq            NaN   4999        268      2697        70       2     463
# mean    2020.507702    NaN        NaN       NaN       NaN     NaN     NaN
# std        3.711361    NaN        NaN       NaN       NaN     NaN     NaN
# min     1981.000000    NaN        NaN       NaN       NaN     NaN     NaN
# 25%     2019.000000    NaN        NaN       NaN       NaN     NaN     NaN
# 50%     2022.000000    NaN        NaN       NaN       NaN     NaN     NaN
# 75%     2023.000000    NaN        NaN       NaN       NaN     NaN     NaN
# max     2023.000000    NaN        NaN       NaN       NaN     NaN     NaN
#
#         Comfort_Rating  Interior_Design_Rating  Performance_Rating  \
# ...

# %%
rating.duplicated().value_counts()
# Out:
# False    4998
# True        1
# dtype: int64

# %%
rating = rating.dropna()

# %%
rating.duplicated().value_counts()
# Out:
# False    4385
# dtype: int64

# %%
rating.shape
# Out:
# (4385, 15)

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4385 entries, 0 to 4997
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     4385 non-null   int64
#  1   Make                     4385 non-null   object
#  2   Model                    4385 non-null   object
#  3   Condition                4385 non-null   object
#  4   Price                    4385 non-null   object
#  5   Stock_#                  4385 non-null   object
#  6   Mileage                  4385 non-null   object
#  7   Comfort_Rating           4385 non-null   float64
#  8   Interior_Design_Rating   4385 non-null   float64
#  9   Performance_Rating       4385 non-null   float64
#  10  Value_For_Money_Rating   4385 non-null   float64
#  11  Exterior_Styling_Rating  4385 non-null   float64
#  12  Reliability_Rating       4385 non-null   float64
#  13  State                    4385 non-null   object
# ...

# %%
rating.to_csv("rating_clean.csv", index=False)
